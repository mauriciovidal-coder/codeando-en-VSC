# %% [markdown]
# <a href="https://colab.research.google.com/github/mauriciovidal-coder/codeando-en-VSC/blob/main/Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("holla mundiño\n como estan gente\n");
# Out:
# holla mundiño
#  como estan gente
